# %% [markdown]
# <a href="https://colab.research.google.com/github/ANJANAMB1/Data-science/blob/main/numpy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
x = np.arange(0, 9, 0.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
x = np.arange(0, 9, 0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.plot(x,y_sin)
plt.plot(x,y_cos)
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine','Cosine'])

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
x = np.arange(0, 9, 0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.subplot(2,1,1)
plt.plot(x,y_sin)
plt.title('Sine')
plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('Cosine')
plt.show()

# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
tstimg = img.imread('cat.jpg')
plt.subplot(1,2,1)
plt.imshow(tstimg)
plt.subplot(1,2,2)
plt.imshow(tstimg)

# %%
from google.colab import drive
drive.mount('/content/drive')
